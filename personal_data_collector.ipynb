# %%
##Welcome and Instructions-
print("Welcome to the Interactive Personal Data Collector!")
print("This Personal Data Collector is used to collect and store data from users in an interactive way.")
print()
print("\n--------Collecting User Personal Data-------")
## Collecting the Information from Users-
user_name = input("Enter your name:")
user_age = int(input("Enter your age:"))
user_height = float(input("Enter your height in meters:"))
user_favourite_number = int(input("Enter your favourite number:"))
##Data Processing-
current_year = 2026
user_birth_year = current_year - user_age
#Checking Class and id-
#for user_name-
class_of_name = type(user_name)
address_of_name = id(user_name)
#for user_age-
class_of_age = type(user_age)
address_of_age = id(user_age)
age_in_float = float(user_age)
#for user_height-
class_of_height= type(user_height)
address_of_height = id(user_height)
height_in_int = int(user_height)
#for user_favourite_number-
class_of_number = type(user_favourite_number)
address_of_number = id(user_favourite_number)
number_in_float = float(user_favourite_number)
#for user_birth_year-
class_of_year = type(user_birth_year)
address_of_year = id(user_birth_year)
year_in_float = float(user_birth_year)


print("\n -------The Summary of User Information is-------")
print("The name of user is: {}, type :{} and memory address is {}.".format(user_name, class_of_name, address_of_name))
print("The age of user is: {}, type :{} and memory address is {}.".format(user_age, class_of_age, address_of_age))
print("The height of user is: {}, type :{} and memory address is {}.".format(user_height, class_of_height, address_of_height))
print("The favourite number of user is: {}, type :{} and memory address is {}.".format(user_favourite_number, class_of_number, address_of_number))

print("The birth year of user based on his age is approximately: {}".format(user_birth_year))


print()

print("Thank You! for using the Interactive Personal Data Collector.")
# Out:
# Welcome to the Interactive Personal Data Collector!
# This Personal Data Collector is used to collect and store data from users in an interactive way.
#
#
# --------Collecting User Personal Data-------
# Enter your name: Aiman Zia
# Enter your age: 23
# Enter your height in meters: 1.55
# Enter your favourite number: 5
#  -------The Summary of User Information is-------
# The name of user is: Aiman Zia, type :<class 'str'> and memory address is 1579905513840.
# The age of user is: 23, type :<class 'int'> and memory address is 140716675085928.
# The height of user is: 1.55, type :<class 'float'> and memory address is 1579889111760.
# The favourite number of user is: 5, type :<class 'int'> and memory address is 140716675085352.
# The birth year of user based on his age is approximately: 2003
#
# Thank You! for using the Interactive Personal Data Collector.
